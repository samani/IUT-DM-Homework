# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('hepatitis.csv', sep=',')
# df = pd.read_csv('hepatitis.csv', sep=',', dtype={'AGE':int,'BILIRUBIN':float,'ALK_PHOSPHATE':int,'SGOT':int,'ALBUMIN':float,'PROTIME':int})
# include =['object','float', 'int']
df.describe(include=include)
# Out:
#                AGE     SEX STEROID ANTIVIRALS FATIGUE MALAISE ANOREXIA  \
# count   155.000000     155     155        155     155     155      155
# unique         NaN       2       3          2       3       3        3
# top            NaN  female     yes         no     yes      no       no
# freq           NaN     139      78        131     100      93      122
# mean     41.200000     NaN     NaN        NaN     NaN     NaN      NaN
# std      12.565878     NaN     NaN        NaN     NaN     NaN      NaN
# min       7.000000     NaN     NaN        NaN     NaN     NaN      NaN
# 25%      32.000000     NaN     NaN        NaN     NaN     NaN      NaN
# 50%      39.000000     NaN     NaN        NaN     NaN     NaN      NaN
# 75%      50.000000     NaN     NaN        NaN     NaN     NaN      NaN
# max      78.000000     NaN     NaN        NaN     NaN     NaN      NaN
#
#        LIVER_BIG LIVER_FIRM SPLEEN_PALPABLE SPIDERS ASCITES VARICES BILIRUBIN  \
# ...
