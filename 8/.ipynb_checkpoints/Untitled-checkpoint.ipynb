# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
matplotlib.style.use('ggplot')

df = pd.read_csv('smartphone.csv', sep=',')
df.head(10)
sns.pairplot(df)
# sns.pairplot(df, hue = 'OS')

# %%
from pydoc import help
from scipy.stats.stats import pearsonr
df.head(10)
pearsonr(df['Weight'],df['inch'])
# Out:
# (0.8457155883705421, 0.004070587968433706)

# %%
df.corr(method ='pearson').style.format("{:.2}").background_gradient(cmap=plt.get_cmap('coolwarm'), axis=1)
# df.corr(method ='spearman')
# df.corr(method ='kendall')
# Out:
# <style  type="text/css" >
#     #T_0eb5b328_5791_11e9_ae92_000c29a07f6arow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_0eb5b328_5791_11e9_ae92_000c29a07f6arow0_col1 {
#             background-color:  #cedaeb;
#             color:  #000000;
#         }    #T_0eb5b328_5791_11e9_ae92_000c29a07f6arow0_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_0eb5b328_5791_11e9_ae92_000c29a07f6arow0_col3 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_0eb5b328_5791_11e9_ae92_000c29a07f6arow1_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_0eb5b328_5791_11e9_ae92_000c29a07f6arow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_0eb5b328_5791_11e9_ae92_000c29a07f6arow1_col2 {
#             background-color:  #5977e3;
#             color:  #000000;
# ...

# %%
df.head()
heatmap1_data = pd.pivot_table(df, values='Weight', index=['Company'], columns='inch')
sns.heatmap(heatmap1_data, cmap="YlGnBu")

# %%
from scipy.stats.stats import spearmanr

coef, p = spearmanr(df['Company'], df['OS'], nan_policy='propagate')
print('Spearmans correlation coefficient: %.3f' % coef)
alpha = 0.05
if p > alpha:
    print('Samples are uncorrelated (fail to reject H0) p=%.3f' % p)
else:
    print('Samples are correlated (reject H0) p=%.3f' % p)
# Out:
# Spearmans correlation coefficient: -0.562
# Samples are uncorrelated (fail to reject H0) p=0.115
# /home/rasool/.local/lib/python3.6/site-packages/scipy/stats/stats.py:248: RuntimeWarning: The input array could not be properly checked for nan values. nan values will be ignored.
#   "values. nan values will be ignored.", RuntimeWarning)
